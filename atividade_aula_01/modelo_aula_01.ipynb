# %% [markdown]
# <a href="https://colab.research.google.com/github/tacianylima-santacruz/python_sis_26_2/blob/main/atividade_aula_01/modelo_aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01

# %% [markdown]
# Atividade Variáveis

# %%
#Código aqui

# %% [markdown]
# Atividade Doc

# %%
#Código aqui

# %% [markdown]
# Atividade input/output

# %%
#Código aqui

# %%
Atividade Operadores

# %%
#Código aqui
